# %% [markdown]
# ## **Introduction: Analyzing User Metrics and Keyword Performance**
#
# ## Demographics
#
# In this analysis, I explored the relationship between user demographics (gender and age) and impressions. The goal was to understand if there were statistically significant differences between men and women impression amounts and if age had any impact on impressions.
#
# To achieve this, I applied a series of hypothesis tests and analysis of variance (ANOVA) techniques, including:
#
# 1. **Hypothesis Test for Gender Differences**: I performed a hypothesis test using a two-way z-test to determine whether women had more impressions men. Using the resultant p-value and an alpha of 0.05, it was proven women have a statisitically different amount of impressions.
#
# 2. **One-Way ANOVA for Age Effect with Post-Hoc Tukey Test**: I conducted a one-way ANOVA to assess whether age influenced impressions, as it was revealed gender does. The test revealed that age has a moderate effect on the amount of impressions, with a p-value less thabn 0.1 but bigger than 0.05. This suggests further investigation should be done for age and its effect on impressions, but it could still be considered as relevant.
#   - The post-hoc test found age groups 18-25 and 65+ to be the most different, with 25-25 having the most impressions and 65+ having the least.
#
# 3. **Two-Way ANOVA**: To refine the analysis, a two-way ANOVA with a post-hoc Tukey test was applied to assess the effect of both age and gender on conversion rates. Using a 0.05 value for alpha, there was no significant difference between any of the categories as the p-value for all categories was NAN. This does not actually mean there is no difference, but that there needs to be more data gathered to get a meaningful result.
#   - Since this did not turn out any results, it is hard to tell what gender and age group will get the most amount of impressions. However, it was proven that women got significantly more impressions than men, and that age group 25-35 got the most impressions, so it isn't far-fetched to say that women in the 25-35 age group will have the most impressions.
#
# ## Time Analysis
#
# 1. **Start Hour ANOVA with Post-Hoc Tukey Test** I conducted an ANOVA test for impressions by hour of the day. The results showed no significant variance between hours, even with a p-value < 0.1. However, I did identify that the top 5 times impressions were during lunch and dinner hours, with the peak time being over 100 impressions. The top 5 times, in order, were: 7 PM, 8 PM, 1 PM, 2 PM, 11 AM. These all occurr either during the evening when people are generally more available after work and school, or during a lunch break period.
#
# 2. **Weekday ANOVA Test with Post-Hoc Tukey Test** I performed a one-way ANOVA test to determine if there was a significant difference in impressions for different days of the week. The results revealed there is no significant difference when using an alpha of 0.05. Overall, Tuesday had the most impressions followed by Friday, with Thursday having the least amount of impressions. To further explore the differences between the days, I used a post-hoc Tukey test, which compared all the days in pairs. This again revealed no signifcant difference between days as none had a p-value less than 0.1.
#
# ## Keyword Analysis
#
# **Keyword Search ANOVA Test with Post-Hoc Tukey Test** To evaulte if there was any significant differenfe between the use of keywords, I conducted an ANOVA test using the keywords and the clicks recieved. This revealed that there is no significant difference between keywords, even with a p-value < 0.1. The leading three keywords were as follows: 'things to do', 'Things to do with family', and 'Things to do with kids'. They had 54, 19, and 14 clicks in that order. The 4th keyword was 'things to do near me' but it had a steep fall off of clicks, recieving only 6, and the rest recieving under 5. From this, I gather the folliwng
#  - Two of the top keywords contain family-oriented words, such as family or kids. This suggests that the link was clicked by those looking to do something fun with their children and should be considered for future target demographics.
#  - Two other top keywords contained relationship-oriented words, such as date idea or couples idea. While these keywords recieved less clicks than the above, this still sugggests the link was clicked by those with a partner looking to do something fun, and should be considered for future demopgrahics as well.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
camp_data = pd.read_csv('google ads campaign data.csv')

# %%
time_data = pd.read_csv('Day_&_hour(Day_Hour).csv')

# %%
dem_data = pd.read_csv('Demographics(Gender_Age_2024.09.01-2024.09.30).csv')

# %%
keyword_data = pd.read_csv('google ads keyword search.csv')

# %%
dem_data.head()
# Out:
#   Gender Age Range  Impressions Percent of known total
# 0   Male     18-24           73                  7.95%
# 1   Male     25-34           98                 10.68%
# 2   Male     35-44           87                  9.48%
# 3   Male     45-54           36                  3.92%
# 4   Male     55-64           16                  1.74%

# %%
dem_data.groupby('Gender')['Impressions'].sum()
# Out:
# Gender
# Female    595
# Male      323
# Name: Impressions, dtype: int64

# %%
from scipy import stats
from statsmodels.stats.proportion import proportions_ztest
#Use a 2-sample z proportion test to see if the amount of impressions is significantly different for women and men.

male_impressions = 595  # Total number of male impressions
female_impressions = 323  # Total number of female impressions
total_impressions = male_impressions + female_impressions  # Combined total impressions

# Count of male and female viewers
imp_counts = np.array([male_impressions, female_impressions])

# Number of groups (two groups: male and female)
impressions_n = np.array([total_impressions, total_impressions])  # Number of total impressions in each group

# Perform a z-test for proportions
stat_impressions, p_value_impressions = proportions_ztest(imp_counts, impressions_n)

# Print results

print(f"Z-statistic: {stat_impressions}")
print(f"P-value: {p_value_impressions}")

# Interpret the result
alpha = 0.05  # Significance level of 5%

if p_value_impressions < alpha:
    print("Reject the null hypothesis: There is a significant difference between male and female impressions.")
else:
    print("Fail to reject the null hypothesis: No significant difference between male and female impressions.")
# Out:
# Z-statistic: 12.695872761853956
# P-value: 6.233119277895775e-37
# Reject the null hypothesis: There is a significant difference between male and female impressions.

# %%
import scipy.stats as stats

# One-way ANOVA: Testing impressions across different Age Groups
age_groups = dem_data['Age Range']
impressions = dem_data['Impressions']

# Perform the one-way ANOVA
f_stat, p_value = stats.f_oneway(
    *[impressions[age_groups == group] for group in dem_data['Age Range'].unique()]
)

# Output the results
print(f"F-statistic: {f_stat}")
print(f"P-value: {p_value}")

# Decision based on p-value
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between age groups.")
elif p_value < 0.1:
    print("Moderate evidence against the null hypothesis: There is a moderate difference between age groups.")
else:
    print("Fail to reject the null hypothesis: No significant difference between age groups.")
# Out:
# F-statistic: 3.5288814691151917
# P-value: 0.07823528439346275
# Moderate evidence against the null hypothesis: There is a moderate difference between age groups.

# %%
# Perform post-hoc test using tukey HSD to see if any pairs have a p value of under 0.1 or close
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Perform Tukey's HSD test
tukey_results = pairwise_tukeyhsd(dem_data['Impressions'], dem_data['Age Range'], alpha=0.05)

# Display Tukey's test results
print(tukey_results)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#  18-24  25-34     69.5 0.6059  -99.2098 238.2098  False
#  18-24  35-44     45.0 0.8804 -123.7098 213.7098  False
#  18-24  45-54    -25.0  0.988 -193.7098 143.7098  False
#  18-24  55-64    -62.5 0.6904 -231.2098 106.2098  False
#  18-24    65+    -69.0 0.6119 -237.7098  99.7098  False
#  25-34  35-44    -24.5  0.989 -193.2098 144.2098  False
#  25-34  45-54    -94.5 0.3431 -263.2098  74.2098  False
#  25-34  55-64   -132.0  0.129 -300.7098  36.7098  False
#  25-34    65+   -138.5 0.1087 -307.2098  30.2098  False
#  35-44  45-54    -70.0 0.5999 -238.7098  98.7098  False
#  35-44  55-64   -107.5 0.2461 -276.2098  61.2098  False
#  35-44    65+   -114.0 0.2076 -282.7098  54.7098  False
#  45-54  55-64    -37.5 0.9373 -206.2098 131.2098  False
#  45-54    65+    -44.0 0.8891 -212.7098 124.7098  False
#  55-64    65+     -6.5    1.0 -175.2098 162.2098  False
# -------------------------------------------------------

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

# Perform Two-Way ANOVA for age and gender
model = ols('Q("Impressions") ~ C(Q("Age Range")) + C(Gender) + C(Q("Age Range")):C(Gender)', data=dem_data).fit()

# Get the ANOVA table
anova_table = anova_lm(model)

# Output the results
print(anova_table)
# Out:
#                               df        sum_sq      mean_sq    F  PR(>F)
# C(Q("Age Range"))            5.0  3.170700e+04  6341.400000  0.0     NaN
# C(Gender)                    1.0  6.165333e+03  6165.333333  0.0     NaN
# C(Q("Age Range")):C(Gender)  5.0  4.616667e+03   923.333333  0.0     NaN
# Residual                     0.0  1.798603e-26          inf  NaN     NaN
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/anova.py:142: RuntimeWarning: divide by zero encountered in scalar divide
#   (model.ssr / model.df_resid))

# %%
time_data.head()
# Out:
#       Day Start Hour  Impressions
# 0  Sunday      12 AM            0
# 1  Sunday       1 AM            0
# 2  Sunday       2 AM            0
# 3  Sunday       3 AM            0
# 4  Sunday       4 AM            0

# %%
import scipy.stats as stats

# One-way ANOVA: Testing impressions across different start times
time_groups = time_data['Start Hour']
impressions = time_data['Impressions']

# Perform the one-way ANOVA
f_stat, p_value = stats.f_oneway(
    *[impressions[time_groups == group] for group in time_data['Start Hour'].unique()]
)

# Output the results
print(f"F-statistic: {f_stat}")
print(f"P-value: {p_value}")

# Decision based on p-value
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between start times.")
elif p_value < 0.1:
    print("Moderate evidence against the null hypothesis: There is a moderate difference between start times.")
else:
    print("Fail to reject the null hypothesis: No significant difference between start times.")
# Out:
# F-statistic: 1.063306158076331
# P-value: 0.3932769358453878
# Fail to reject the null hypothesis: No significant difference between start times.

# %%
# Perform post-hoc test using tukey HSD to see if any pairs have a p value of under 0.1 or close
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Perform Tukey's HSD test
tukey_results = pairwise_tukeyhsd(time_data['Impressions'], time_data['Start Hour'], alpha=0.05)

# Display Tukey's test results
print(tukey_results)
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#  10 AM  10 PM  -1.7143    1.0 -27.8559 24.4273  False
#  10 AM  11 AM   3.2857    1.0 -22.8559 29.4273  False
#  10 AM  11 PM  -5.2857    1.0 -31.4273 20.8559  False
#  10 AM  12 AM  -1.1429    1.0 -27.2845 24.9988  False
#  10 AM  12 PM   4.8571    1.0 -21.2845 30.9988  False
#  10 AM   1 AM  -2.2857    1.0 -28.4273 23.8559  False
#  10 AM   1 PM      5.0    1.0 -21.1416 31.1416  False
#  10 AM   2 AM  -4.1429    1.0 -30.2845 21.9988  False
#  10 AM   2 PM   3.1429    1.0 -22.9988 29.2845  False
#  10 AM   3 AM     -3.0    1.0 -29.1416 23.1416  False
#  10 AM   3 PM  -0.4286    1.0 -26.5702 25.7131  False
#  10 AM   4 AM  -3.2857    1.0 -29.4273 22.8559  False
#  10 AM   4 PM   2.8571    1.0 -23.2845 28.9988  False
#  10 AM   5 AM  -2.7143    1.0 -28.8559 23.4273  False
#  10 AM   5 PM   1.2857    1.0 -24.8559 27.4273  False
#  10 AM   6 AM     -4.0    1.0 -30.1416 22.1416  False
#  10 AM   6 PM   0.7143    1.0 -25.4273 26.8559  False
#  10 AM   7 AM  -4.4286    1.0 -30.5702 21.7131  False
#  10 AM   7 PM  18.8571 0.5403  -7.2845 44.9988  False
#  10 AM   8 AM  -1.8571    1.0 -27.9988 24.2845  False
#  10 AM   8 PM   7.1429    1.0 -18.9988 33.2845  False
#  10 AM   9 AM   2.1429    1.0 -23.9988 28.2845  False
#  10 AM   9 PM  -1.7143    1.0 -27.8559 24.4273  False
#  10 PM  11 AM      5.0    1.0 -21.1416 31.1416  False
#  10 PM  11 PM  -3.5714    1.0 -29.7131 22.5702  False
#  10 PM  12 AM   0.5714    1.0 -25.5702 26.7131  False
#  10 PM  12 PM   6.5714    1.0 -19.5702 32.7131  False
#  10 PM   1 AM  -0.5714    1.0 -26.7131 25.5702  False
#  10 PM   1 PM   6.7143    1.0 -19.4273 32.8559  False
#  10 PM   2 AM  -2.4286    1.0 -28.5702 23.7131  False
#  10 PM   2 PM   4.8571    1.0 -21.2845 30.9988  False
#  10 PM   3 AM  -1.2857    1.0 -27.4273 24.8559  False
#  10 PM   3 PM   1.2857    1.0 -24.8559 27.4273  False
#  10 PM   4 AM  -1.5714    1.0 -27.7131 24.5702  False
#  10 PM   4 PM   4.5714    1.0 -21.5702 30.7131  False
#  10 PM   5 AM     -1.0    1.0 -27.1416 25.1416  False
#  10 PM   5 PM      3.0    1.0 -23.1416 29.1416  False
#  10 PM   6 AM  -2.2857    1.0 -28.4273 23.8559  False
#  10 PM   6 PM   2.4286    1.0 -23.7131 28.5702  False
#  10 PM   7 AM  -2.7143    1.0 -28.8559 23.4273  False
#  10 PM   7 PM  20.5714 0.3618  -5.5702 46.7131  False
#  10 PM   8 AM  -0.1429    1.0 -26.2845 25.9988  False
#  10 PM   8 PM   8.8571 0.9999 -17.2845 34.9988  False
#  10 PM   9 AM   3.8571    1.0 -22.2845 29.9988  False
#  10 PM   9 PM      0.0    1.0 -26.1416 26.1416  False
#  11 AM  11 PM  -8.5714 0.9999 -34.7131 17.5702  False
#  11 AM  12 AM  -4.4286    1.0 -30.5702 21.7131  False
#  11 AM  12 PM   1.5714    1.0 -24.5702 27.7131  False
#  11 AM   1 AM  -5.5714    1.0 -31.7131 20.5702  False
#  11 AM   1 PM   1.7143    1.0 -24.4273 27.8559  False
#  11 AM   2 AM  -7.4286    1.0 -33.5702 18.7131  False
#  11 AM   2 PM  -0.1429    1.0 -26.2845 25.9988  False
#  11 AM   3 AM  -6.2857    1.0 -32.4273 19.8559  False
#  11 AM   3 PM  -3.7143    1.0 -29.8559 22.4273  False
#  11 AM   4 AM  -6.5714    1.0 -32.7131 19.5702  False
#  11 AM   4 PM  -0.4286    1.0 -26.5702 25.7131  False
#  11 AM   5 AM     -6.0    1.0 -32.1416 20.1416  False
#  11 AM   5 PM     -2.0    1.0 -28.1416 24.1416  False
#  11 AM   6 AM  -7.2857    1.0 -33.4273 18.8559  False
#  11 AM   6 PM  -2.5714    1.0 -28.7131 23.5702  False
#  11 AM   7 AM  -7.7143    1.0 -33.8559 18.4273  False
#  11 AM   7 PM  15.5714 0.8587 -10.5702 41.7131  False
#  11 AM   8 AM  -5.1429    1.0 -31.2845 20.9988  False
#  11 AM   8 PM   3.8571    1.0 -22.2845 29.9988  False
#  11 AM   9 AM  -1.1429    1.0 -27.2845 24.9988  False
#  11 AM   9 PM     -5.0    1.0 -31.1416 21.1416  False
#  11 PM  12 AM   4.1429    1.0 -21.9988 30.2845  False
#  11 PM  12 PM  10.1429  0.999 -15.9988 36.2845  False
#  11 PM   1 AM      3.0    1.0 -23.1416 29.1416  False
#  11 PM   1 PM  10.2857 0.9988 -15.8559 36.4273  False
#  11 PM   2 AM   1.1429    1.0 -24.9988 27.2845  False
#  11 PM   2 PM   8.4286 0.9999 -17.7131 34.5702  False
#  11 PM   3 AM   2.2857    1.0 -23.8559 28.4273  False
#  11 PM   3 PM   4.8571    1.0 -21.2845 30.9988  False
#  11 PM   4 AM      2.0    1.0 -24.1416 28.1416  False
#  11 PM   4 PM   8.1429    1.0 -17.9988 34.2845  False
#  11 PM   5 AM   2.5714    1.0 -23.5702 28.7131  False
#  11 PM   5 PM   6.5714    1.0 -19.5702 32.7131  False
#  11 PM   6 AM   1.2857    1.0 -24.8559 27.4273  False
#  11 PM   6 PM      6.0    1.0 -20.1416 32.1416  False
#  11 PM   7 AM   0.8571    1.0 -25.2845 26.9988  False
#  11 PM   7 PM  24.1429 0.1132  -1.9988 50.2845  False
#  11 PM   8 AM   3.4286    1.0 -22.7131 29.5702  False
#  11 PM   8 PM  12.4286 0.9848 -13.7131 38.5702  False
#  11 PM   9 AM   7.4286    1.0 -18.7131 33.5702  False
#  11 PM   9 PM   3.5714    1.0 -22.5702 29.7131  False
#  12 AM  12 PM      6.0    1.0 -20.1416 32.1416  False
#  12 AM   1 AM  -1.1429    1.0 -27.2845 24.9988  False
#  12 AM   1 PM   6.1429    1.0 -19.9988 32.2845  False
#  12 AM   2 AM     -3.0    1.0 -29.1416 23.1416  False
#  12 AM   2 PM   4.2857    1.0 -21.8559 30.4273  False
#  12 AM   3 AM  -1.8571    1.0 -27.9988 24.2845  False
#  12 AM   3 PM   0.7143    1.0 -25.4273 26.8559  False
#  12 AM   4 AM  -2.1429    1.0 -28.2845 23.9988  False
#  12 AM   4 PM      4.0    1.0 -22.1416 30.1416  False
#  12 AM   5 AM  -1.5714    1.0 -27.7131 24.5702  False
#  12 AM   5 PM   2.4286    1.0 -23.7131 28.5702  False
#  12 AM   6 AM  -2.8571    1.0 -28.9988 23.2845  False
#  12 AM   6 PM   1.8571    1.0 -24.2845 27.9988  False
#  12 AM   7 AM  -3.2857    1.0 -29.4273 22.8559  False
#  12 AM   7 PM     20.0 0.4185  -6.1416 46.1416  False
#  12 AM   8 AM  -0.7143    1.0 -26.8559 25.4273  False
#  12 AM   8 PM   8.2857    1.0 -17.8559 34.4273  False
#  12 AM   9 AM   3.2857    1.0 -22.8559 29.4273  False
#  12 AM   9 PM  -0.5714    1.0 -26.7131 25.5702  False
#  12 PM   1 AM  -7.1429    1.0 -33.2845 18.9988  False
#  12 PM   1 PM   0.1429    1.0 -25.9988 26.2845  False
#  12 PM   2 AM     -9.0 0.9998 -35.1416 17.1416  False
#  12 PM   2 PM  -1.7143    1.0 -27.8559 24.4273  False
#  12 PM   3 AM  -7.8571    1.0 -33.9988 18.2845  False
#  12 PM   3 PM  -5.2857    1.0 -31.4273 20.8559  False
#  12 PM   4 AM  -8.1429    1.0 -34.2845 17.9988  False
#  12 PM   4 PM     -2.0    1.0 -28.1416 24.1416  False
#  12 PM   5 AM  -7.5714    1.0 -33.7131 18.5702  False
#  12 PM   5 PM  -3.5714    1.0 -29.7131 22.5702  False
#  12 PM   6 AM  -8.8571 0.9999 -34.9988 17.2845  False
#  12 PM   6 PM  -4.1429    1.0 -30.2845 21.9988  False
#  12 PM   7 AM  -9.2857 0.9997 -35.4273 16.8559  False
#  12 PM   7 PM     14.0 0.9449 -12.1416 40.1416  False
#  12 PM   8 AM  -6.7143    1.0 -32.8559 19.4273  False
#  12 PM   8 PM   2.2857    1.0 -23.8559 28.4273  False
#  12 PM   9 AM  -2.7143    1.0 -28.8559 23.4273  False
#  12 PM   9 PM  -6.5714    1.0 -32.7131 19.5702  False
#   1 AM   1 PM   7.2857    1.0 -18.8559 33.4273  False
#   1 AM   2 AM  -1.8571    1.0 -27.9988 24.2845  False
#   1 AM   2 PM   5.4286    1.0 -20.7131 31.5702  False
#   1 AM   3 AM  -0.7143    1.0 -26.8559 25.4273  False
#   1 AM   3 PM   1.8571    1.0 -24.2845 27.9988  False
#   1 AM   4 AM     -1.0    1.0 -27.1416 25.1416  False
#   1 AM   4 PM   5.1429    1.0 -20.9988 31.2845  False
#   1 AM   5 AM  -0.4286    1.0 -26.5702 25.7131  False
#   1 AM   5 PM   3.5714    1.0 -22.5702 29.7131  False
#   1 AM   6 AM  -1.7143    1.0 -27.8559 24.4273  False
#   1 AM   6 PM      3.0    1.0 -23.1416 29.1416  False
#   1 AM   7 AM  -2.1429    1.0 -28.2845 23.9988  False
#   1 AM   7 PM  21.1429 0.3091  -4.9988 47.2845  False
#   1 AM   8 AM   0.4286    1.0 -25.7131 26.5702  False
#   1 AM   8 PM   9.4286 0.9997 -16.7131 35.5702  False
#   1 AM   9 AM   4.4286    1.0 -21.7131 30.5702  False
#   1 AM   9 PM   0.5714    1.0 -25.5702 26.7131  False
#   1 PM   2 AM  -9.1429 0.9998 -35.2845 16.9988  False
#   1 PM   2 PM  -1.8571    1.0 -27.9988 24.2845  False
#   1 PM   3 AM     -8.0    1.0 -34.1416 18.1416  False
#   1 PM   3 PM  -5.4286    1.0 -31.5702 20.7131  False
#   1 PM   4 AM  -8.2857    1.0 -34.4273 17.8559  False
#   1 PM   4 PM  -2.1429    1.0 -28.2845 23.9988  False
#   1 PM   5 AM  -7.7143    1.0 -33.8559 18.4273  False
#   1 PM   5 PM  -3.7143    1.0 -29.8559 22.4273  False
#   1 PM   6 AM     -9.0 0.9998 -35.1416 17.1416  False
#   1 PM   6 PM  -4.2857    1.0 -30.4273 21.8559  False
#   1 PM   7 AM  -9.4286 0.9997 -35.5702 16.7131  False
#   1 PM   7 PM  13.8571 0.9503 -12.2845 39.9988  False
#   1 PM   8 AM  -6.8571    1.0 -32.9988 19.2845  False
#   1 PM   8 PM   2.1429    1.0 -23.9988 28.2845  False
#   1 PM   9 AM  -2.8571    1.0 -28.9988 23.2845  False
#   1 PM   9 PM  -6.7143    1.0 -32.8559 19.4273  False
#   2 AM   2 PM   7.2857    1.0 -18.8559 33.4273  False
#   2 AM   3 AM   1.1429    1.0 -24.9988 27.2845  False
#   2 AM   3 PM   3.7143    1.0 -22.4273 29.8559  False
#   2 AM   4 AM   0.8571    1.0 -25.2845 26.9988  False
#   2 AM   4 PM      7.0    1.0 -19.1416 33.1416  False
#   2 AM   5 AM   1.4286    1.0 -24.7131 27.5702  False
#   2 AM   5 PM   5.4286    1.0 -20.7131 31.5702  False
#   2 AM   6 AM   0.1429    1.0 -25.9988 26.2845  False
#   2 AM   6 PM   4.8571    1.0 -21.2845 30.9988  False
#   2 AM   7 AM  -0.2857    1.0 -26.4273 25.8559  False
#   2 AM   7 PM     23.0 0.1716  -3.1416 49.1416  False
#   2 AM   8 AM   2.2857    1.0 -23.8559 28.4273  False
#   2 AM   8 PM  11.2857 0.9955 -14.8559 37.4273  False
#   2 AM   9 AM   6.2857    1.0 -19.8559 32.4273  False
#   2 AM   9 PM   2.4286    1.0 -23.7131 28.5702  False
#   2 PM   3 AM  -6.1429    1.0 -32.2845 19.9988  False
#   2 PM   3 PM  -3.5714    1.0 -29.7131 22.5702  False
#   2 PM   4 AM  -6.4286    1.0 -32.5702 19.7131  False
#   2 PM   4 PM  -0.2857    1.0 -26.4273 25.8559  False
#   2 PM   5 AM  -5.8571    1.0 -31.9988 20.2845  False
#   2 PM   5 PM  -1.8571    1.0 -27.9988 24.2845  False
#   2 PM   6 AM  -7.1429    1.0 -33.2845 18.9988  False
#   2 PM   6 PM  -2.4286    1.0 -28.5702 23.7131  False
#   2 PM   7 AM  -7.5714    1.0 -33.7131 18.5702  False
#   2 PM   7 PM  15.7143 0.8483 -10.4273 41.8559  False
#   2 PM   8 AM     -5.0    1.0 -31.1416 21.1416  False
#   2 PM   8 PM      4.0    1.0 -22.1416 30.1416  False
#   2 PM   9 AM     -1.0    1.0 -27.1416 25.1416  False
#   2 PM   9 PM  -4.8571    1.0 -30.9988 21.2845  False
#   3 AM   3 PM   2.5714    1.0 -23.5702 28.7131  False
#   3 AM   4 AM  -0.2857    1.0 -26.4273 25.8559  False
#   3 AM   4 PM   5.8571    1.0 -20.2845 31.9988  False
#   3 AM   5 AM   0.2857    1.0 -25.8559 26.4273  False
#   3 AM   5 PM   4.2857    1.0 -21.8559 30.4273  False
#   3 AM   6 AM     -1.0    1.0 -27.1416 25.1416  False
#   3 AM   6 PM   3.7143    1.0 -22.4273 29.8559  False
#   3 AM   7 AM  -1.4286    1.0 -27.5702 24.7131  False
#   3 AM   7 PM  21.8571 0.2498  -4.2845 47.9988  False
#   3 AM   8 AM   1.1429    1.0 -24.9988 27.2845  False
#   3 AM   8 PM  10.1429  0.999 -15.9988 36.2845  False
#   3 AM   9 AM   5.1429    1.0 -20.9988 31.2845  False
#   3 AM   9 PM   1.2857    1.0 -24.8559 27.4273  False
#   3 PM   4 AM  -2.8571    1.0 -28.9988 23.2845  False
#   3 PM   4 PM   3.2857    1.0 -22.8559 29.4273  False
#   3 PM   5 AM  -2.2857    1.0 -28.4273 23.8559  False
#   3 PM   5 PM   1.7143    1.0 -24.4273 27.8559  False
#   3 PM   6 AM  -3.5714    1.0 -29.7131 22.5702  False
#   3 PM   6 PM   1.1429    1.0 -24.9988 27.2845  False
#   3 PM   7 AM     -4.0    1.0 -30.1416 22.1416  False
#   3 PM   7 PM  19.2857 0.4937  -6.8559 45.4273  False
#   3 PM   8 AM  -1.4286    1.0 -27.5702 24.7131  False
#   3 PM   8 PM   7.5714    1.0 -18.5702 33.7131  False
#   3 PM   9 AM   2.5714    1.0 -23.5702 28.7131  False
#   3 PM   9 PM  -1.2857    1.0 -27.4273 24.8559  False
#   4 AM   4 PM   6.1429    1.0 -19.9988 32.2845  False
#   4 AM   5 AM   0.5714    1.0 -25.5702 26.7131  False
#   4 AM   5 PM   4.5714    1.0 -21.5702 30.7131  False
#   4 AM   6 AM  -0.7143    1.0 -26.8559 25.4273  False
#   4 AM   6 PM      4.0    1.0 -22.1416 30.1416  False
#   4 AM   7 AM  -1.1429    1.0 -27.2845 24.9988  False
#   4 AM   7 PM  22.1429 0.2283  -3.9988 48.2845  False
#   4 AM   8 AM   1.4286    1.0 -24.7131 27.5702  False
#   4 AM   8 PM  10.4286 0.9985 -15.7131 36.5702  False
#   4 AM   9 AM   5.4286    1.0 -20.7131 31.5702  False
#   4 AM   9 PM   1.5714    1.0 -24.5702 27.7131  False
#   4 PM   5 AM  -5.5714    1.0 -31.7131 20.5702  False
#   4 PM   5 PM  -1.5714    1.0 -27.7131 24.5702  False
#   4 PM   6 AM  -6.8571    1.0 -32.9988 19.2845  False
#   4 PM   6 PM  -2.1429    1.0 -28.2845 23.9988  False
#   4 PM   7 AM  -7.2857    1.0 -33.4273 18.8559  False
#   4 PM   7 PM     16.0 0.8261 -10.1416 42.1416  False
#   4 PM   8 AM  -4.7143    1.0 -30.8559 21.4273  False
#   4 PM   8 PM   4.2857    1.0 -21.8559 30.4273  False
#   4 PM   9 AM  -0.7143    1.0 -26.8559 25.4273  False
#   4 PM   9 PM  -4.5714    1.0 -30.7131 21.5702  False
#   5 AM   5 PM      4.0    1.0 -22.1416 30.1416  False
#   5 AM   6 AM  -1.2857    1.0 -27.4273 24.8559  False
#   5 AM   6 PM   3.4286    1.0 -22.7131 29.5702  False
#   5 AM   7 AM  -1.7143    1.0 -27.8559 24.4273  False
#   5 AM   7 PM  21.5714 0.2726  -4.5702 47.7131  False
#   5 AM   8 AM   0.8571    1.0 -25.2845 26.9988  False
#   5 AM   8 PM   9.8571 0.9994 -16.2845 35.9988  False
#   5 AM   9 AM   4.8571    1.0 -21.2845 30.9988  False
#   5 AM   9 PM      1.0    1.0 -25.1416 27.1416  False
#   5 PM   6 AM  -5.2857    1.0 -31.4273 20.8559  False
#   5 PM   6 PM  -0.5714    1.0 -26.7131 25.5702  False
#   5 PM   7 AM  -5.7143    1.0 -31.8559 20.4273  False
#   5 PM   7 PM  17.5714 0.6789  -8.5702 43.7131  False
#   5 PM   8 AM  -3.1429    1.0 -29.2845 22.9988  False
#   5 PM   8 PM   5.8571    1.0 -20.2845 31.9988  False
#   5 PM   9 AM   0.8571    1.0 -25.2845 26.9988  False
#   5 PM   9 PM     -3.0    1.0 -29.1416 23.1416  False
#   6 AM   6 PM   4.7143    1.0 -21.4273 30.8559  False
#   6 AM   7 AM  -0.4286    1.0 -26.5702 25.7131  False
#   6 AM   7 PM  22.8571 0.1803  -3.2845 48.9988  False
#   6 AM   8 AM   2.1429    1.0 -23.9988 28.2845  False
#   6 AM   8 PM  11.1429 0.9962 -14.9988 37.2845  False
#   6 AM   9 AM   6.1429    1.0 -19.9988 32.2845  False
#   6 AM   9 PM   2.2857    1.0 -23.8559 28.4273  False
#   6 PM   7 AM  -5.1429    1.0 -31.2845 20.9988  False
#   6 PM   7 PM  18.1429 0.6181  -7.9988 44.2845  False
#   6 PM   8 AM  -2.5714    1.0 -28.7131 23.5702  False
#   6 PM   8 PM   6.4286    1.0 -19.7131 32.5702  False
#   6 PM   9 AM   1.4286    1.0 -24.7131 27.5702  False
#   6 PM   9 PM  -2.4286    1.0 -28.5702 23.7131  False
#   7 AM   7 PM  23.2857 0.1552  -2.8559 49.4273  False
#   7 AM   8 AM   2.5714    1.0 -23.5702 28.7131  False
#   7 AM   8 PM  11.5714 0.9938 -14.5702 37.7131  False
#   7 AM   9 AM   6.5714    1.0 -19.5702 32.7131  False
#   7 AM   9 PM   2.7143    1.0 -23.4273 28.8559  False
#   7 PM   8 AM -20.7143 0.3482 -46.8559  5.4273  False
#   7 PM   8 PM -11.7143 0.9927 -37.8559 14.4273  False
#   7 PM   9 AM -16.7143  0.764 -42.8559  9.4273  False
#   7 PM   9 PM -20.5714 0.3618 -46.7131  5.5702  False
#   8 AM   8 PM      9.0 0.9998 -17.1416 35.1416  False
#   8 AM   9 AM      4.0    1.0 -22.1416 30.1416  False
#   8 AM   9 PM   0.1429    1.0 -25.9988 26.2845  False
#   8 PM   9 AM     -5.0    1.0 -31.1416 21.1416  False
#   8 PM   9 PM  -8.8571 0.9999 -34.9988 17.2845  False
#   9 AM   9 PM  -3.8571    1.0 -29.9988 22.2845  False
# -----------------------------------------------------

# %%
tukey_results.pvalues < 0.1
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False])

# %%
import scipy.stats as stats

# One-way ANOVA: Testing impressions across different weekdays
day_groups = time_data['Day']
impressions = time_data['Impressions']

# Perform the one-way ANOVA
f_stat, p_value = stats.f_oneway(
    *[impressions[day_groups == group] for group in time_data['Day'].unique()]
)

# Output the results
print(f"F-statistic: {f_stat}")
print(f"P-value: {p_value}")

# Decision based on p-value
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between weekdays.")
elif p_value < 0.1:
    print("Moderate evidence against the null hypothesis: There is a moderate difference between weekdays.")
else:
    print("Fail to reject the null hypothesis: No significant difference between weekdays.")
# Out:
# F-statistic: 1.4897284909539539
# P-value: 0.18477399423346366
# Fail to reject the null hypothesis: No significant difference between weekdays.

# %%
# Perform post-hoc test using tukey HSD to see if any pairs have a p value of under 0.1 or close
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Perform Tukey's HSD test
tukey_results = pairwise_tukeyhsd(time_data['Impressions'], time_data['Day'], alpha=0.05)

# Display Tukey's test results
print(tukey_results)
# Out:
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================
#  group1    group2  meandiff p-adj   lower    upper  reject
# ----------------------------------------------------------
#   Friday    Monday  -0.7917    1.0 -12.1071 10.5238  False
#   Friday  Saturday   -2.125 0.9978 -13.4405  9.1905  False
#   Friday    Sunday  -9.2083  0.193 -20.5238  2.1071  False
#   Friday  Thursday   -2.875 0.9884 -14.1905  8.4405  False
#   Friday   Tuesday   0.2083    1.0 -11.1071 11.5238  False
#   Friday Wednesday  -0.7917    1.0 -12.1071 10.5238  False
#   Monday  Saturday  -1.3333 0.9998 -12.6488  9.9821  False
#   Monday    Sunday  -8.4167 0.2902 -19.7321  2.8988  False
#   Monday  Thursday  -2.0833  0.998 -13.3988  9.2321  False
#   Monday   Tuesday      1.0    1.0 -10.3155 12.3155  False
#   Monday Wednesday      0.0    1.0 -11.3155 11.3155  False
# Saturday    Sunday  -7.0833 0.5037 -18.3988  4.2321  False
# Saturday  Thursday    -0.75    1.0 -12.0655 10.5655  False
# Saturday   Tuesday   2.3333 0.9962  -8.9821 13.6488  False
# Saturday Wednesday   1.3333 0.9998  -9.9821 12.6488  False
#   Sunday  Thursday   6.3333 0.6361  -4.9821 17.6488  False
#   Sunday   Tuesday   9.4167 0.1718  -1.8988 20.7321  False
#   Sunday Wednesday   8.4167 0.2902  -2.8988 19.7321  False
# Thursday   Tuesday   3.0833 0.9833  -8.2321 14.3988  False
# Thursday Wednesday   2.0833  0.998  -9.2321 13.3988  False
#  Tuesday Wednesday     -1.0    1.0 -12.3155 10.3155  False
# ----------------------------------------------------------

# %%
keyword_data.head()
# Out:
#              Search Keyword    Match type Criterion Status Campaign Status  \
# 0              things to do  Phrase match          Enabled          Paused
# 1              things to do   Broad match          Removed          Paused
# 2  Things to do with family  Phrase match          Enabled          Paused
# 3    Things to do with kids  Phrase match          Enabled          Paused
# 4      things to do near me  Phrase match          Enabled          Paused
#
#   Ad Group Status    Cost  Clicks Avg. CPC
# 0         Enabled  $17.11      37    $0.46
# 1         Enabled  $11.51      17    $0.68
# 2         Enabled  $10.13      19    $0.53
# 3         Enabled   $7.15      14    $0.51
# 4         Enabled   $3.17       6    $0.53

# %%
import scipy.stats as stats

# One-way ANOVA: Testing impressions across different weekdays
word_groups = keyword_data['Search Keyword']
clicks = keyword_data['Clicks']

# Perform the one-way ANOVA
f_stat, p_value = stats.f_oneway(
    *[clicks[word_groups == group] for group in keyword_data['Search Keyword'].unique()]
)

# Output the results
print(f"F-statistic: {f_stat}")
print(f"P-value: {p_value}")

# Decision based on p-value
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between keyword search clicks.")
elif p_value < 0.1:
    print("Moderate evidence against the null hypothesis: There is a moderate difference between keyword search clicks.")
else:
    print("Fail to reject the null hypothesis: No significant difference between keyword search clicks.")
# Out:
# F-statistic: 0.6061694099419933
# P-value: 0.8610203126042437
# Fail to reject the null hypothesis: No significant difference between keyword search clicks.

# %%
# Perform post-hoc test using tukey HSD to see if any pairs have a p value of under 0.1 or close
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Perform Tukey's HSD test
tukey_results = pairwise_tukeyhsd(keyword_data['Clicks'], keyword_data['Search Keyword'], alpha=0.05)

# Display Tukey's test results
print(tukey_results)
# Out:
#                                 Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================================================================
#                 group1                                group2                meandiff p-adj   lower    upper  reject
# -------------------------------------------------------------------------------------------------------------------
#              Things to do with family  Things to do with family on vacation     -9.5    1.0 -54.9535 35.9535  False
#              Things to do with family Things to do with family this weekend     -9.5    1.0 -54.9535 35.9535  False
#              Things to do with family                Things to do with kids     -2.5    1.0 -39.6127 34.6127  False
#              Things to do with family   Things to do with kids this weekend     -9.5    1.0 -54.9535 35.9535  False
#              Things to do with family                   attractions near me     -9.5 0.9998 -46.6127 27.6127  False
#              Things to do with family           couple date idea fort myers     -9.5    1.0 -54.9535 35.9535  False
#              Things to do with family             couple date ideas near me     -9.5    1.0 -54.9535 35.9535  False
#              Things to do with family            couples activities near me     -9.5    1.0 -54.9535 35.9535  False
#              Things to do with family                   couples dates ideas     -8.5    1.0 -45.6127 28.6127  False
#              Things to do with family                       cute date ideas     -9.0 0.9999 -46.1127 28.1127  False
#              Things to do with family                date idea this weekend     -9.5    1.0 -54.9535 35.9535  False
#              Things to do with family                      date night ideas     -8.0    1.0 -45.1127 29.1127  False
#              Things to do with family              date night ideas near me     -9.5    1.0 -54.9535 35.9535  False
#              Things to do with family             fun activities fort myers     -8.5    1.0 -45.6127 28.6127  False
#              Things to do with family                fun activities near me     -8.5    1.0 -45.6127 28.6127  False
#              Things to do with family                  fun dates fort myers     -9.5 0.9998 -46.6127 27.6127  False
#              Things to do with family  fun places to go with family near me     -9.5    1.0 -54.9535 35.9535  False
#              Things to do with family              fun things to do near me     -9.5 0.9998 -46.6127 27.6127  False
#              Things to do with family          fun things to do with family     -9.5    1.0 -54.9535 35.9535  False
#              Things to do with family              new things to do near me     -9.5    1.0 -54.9535 35.9535  False
#              Things to do with family                          things to do      8.5 0.9998 -25.3791 42.3791  False
#              Things to do with family                  things to do near me     -6.5    1.0 -43.6127 30.6127  False
#              Things to do with family             things to do this weekend     -8.5    1.0 -45.6127 28.6127  False
#  Things to do with family on vacation Things to do with family this weekend      0.0    1.0 -52.4852 52.4852  False
#  Things to do with family on vacation                Things to do with kids      7.0    1.0 -38.4535 52.4535  False
#  Things to do with family on vacation   Things to do with kids this weekend      0.0    1.0 -52.4852 52.4852  False
#  Things to do with family on vacation                   attractions near me      0.0    1.0 -45.4535 45.4535  False
#  Things to do with family on vacation           couple date idea fort myers      0.0    1.0 -52.4852 52.4852  False
#  Things to do with family on vacation             couple date ideas near me      0.0    1.0 -52.4852 52.4852  False
#  Things to do with family on vacation            couples activities near me      0.0    1.0 -52.4852 52.4852  False
#  Things to do with family on vacation                   couples dates ideas      1.0    1.0 -44.4535 46.4535  False
#  Things to do with family on vacation                       cute date ideas      0.5    1.0 -44.9535 45.9535  False
#  Things to do with family on vacation                date idea this weekend      0.0    1.0 -52.4852 52.4852  False
#  Things to do with family on vacation                      date night ideas      1.5    1.0 -43.9535 46.9535  False
#  Things to do with family on vacation              date night ideas near me      0.0    1.0 -52.4852 52.4852  False
#  Things to do with family on vacation             fun activities fort myers      1.0    1.0 -44.4535 46.4535  False
#  Things to do with family on vacation                fun activities near me      1.0    1.0 -44.4535 46.4535  False
#  Things to do with family on vacation                  fun dates fort myers      0.0    1.0 -45.4535 45.4535  False
#  Things to do with family on vacation  fun places to go with family near me      0.0    1.0 -52.4852 52.4852  False
#  Things to do with family on vacation              fun things to do near me      0.0    1.0 -45.4535 45.4535  False
#  Things to do with family on vacation          fun things to do with family      0.0    1.0 -52.4852 52.4852  False
#  Things to do with family on vacation              new things to do near me      0.0    1.0 -52.4852 52.4852  False
#  Things to do with family on vacation                          things to do     18.0 0.9438  -24.854  60.854  False
#  Things to do with family on vacation                  things to do near me      3.0    1.0 -42.4535 48.4535  False
#  Things to do with family on vacation             things to do this weekend      1.0    1.0 -44.4535 46.4535  False
# Things to do with family this weekend                Things to do with kids      7.0    1.0 -38.4535 52.4535  False
# Things to do with family this weekend   Things to do with kids this weekend      0.0    1.0 -52.4852 52.4852  False
# Things to do with family this weekend                   attractions near me      0.0    1.0 -45.4535 45.4535  False
# Things to do with family this weekend           couple date idea fort myers      0.0    1.0 -52.4852 52.4852  False
# Things to do with family this weekend             couple date ideas near me      0.0    1.0 -52.4852 52.4852  False
# Things to do with family this weekend            couples activities near me      0.0    1.0 -52.4852 52.4852  False
# Things to do with family this weekend                   couples dates ideas      1.0    1.0 -44.4535 46.4535  False
# Things to do with family this weekend                       cute date ideas      0.5    1.0 -44.9535 45.9535  False
# Things to do with family this weekend                date idea this weekend      0.0    1.0 -52.4852 52.4852  False
# Things to do with family this weekend                      date night ideas      1.5    1.0 -43.9535 46.9535  False
# Things to do with family this weekend              date night ideas near me      0.0    1.0 -52.4852 52.4852  False
# Things to do with family this weekend             fun activities fort myers      1.0    1.0 -44.4535 46.4535  False
# Things to do with family this weekend                fun activities near me      1.0    1.0 -44.4535 46.4535  False
# Things to do with family this weekend                  fun dates fort myers      0.0    1.0 -45.4535 45.4535  False
# Things to do with family this weekend  fun places to go with family near me      0.0    1.0 -52.4852 52.4852  False
# Things to do with family this weekend              fun things to do near me      0.0    1.0 -45.4535 45.4535  False
# Things to do with family this weekend          fun things to do with family      0.0    1.0 -52.4852 52.4852  False
# Things to do with family this weekend              new things to do near me      0.0    1.0 -52.4852 52.4852  False
# Things to do with family this weekend                          things to do     18.0 0.9438  -24.854  60.854  False
# Things to do with family this weekend                  things to do near me      3.0    1.0 -42.4535 48.4535  False
# Things to do with family this weekend             things to do this weekend      1.0    1.0 -44.4535 46.4535  False
#                Things to do with kids   Things to do with kids this weekend     -7.0    1.0 -52.4535 38.4535  False
#                Things to do with kids                   attractions near me     -7.0    1.0 -44.1127 30.1127  False
#                Things to do with kids           couple date idea fort myers     -7.0    1.0 -52.4535 38.4535  False
#                Things to do with kids             couple date ideas near me     -7.0    1.0 -52.4535 38.4535  False
#                Things to do with kids            couples activities near me     -7.0    1.0 -52.4535 38.4535  False
#                Things to do with kids                   couples dates ideas     -6.0    1.0 -43.1127 31.1127  False
#                Things to do with kids                       cute date ideas     -6.5    1.0 -43.6127 30.6127  False
#                Things to do with kids                date idea this weekend     -7.0    1.0 -52.4535 38.4535  False
#                Things to do with kids                      date night ideas     -5.5    1.0 -42.6127 31.6127  False
#                Things to do with kids              date night ideas near me     -7.0    1.0 -52.4535 38.4535  False
#                Things to do with kids             fun activities fort myers     -6.0    1.0 -43.1127 31.1127  False
#                Things to do with kids                fun activities near me     -6.0    1.0 -43.1127 31.1127  False
#                Things to do with kids                  fun dates fort myers     -7.0    1.0 -44.1127 30.1127  False
#                Things to do with kids  fun places to go with family near me     -7.0    1.0 -52.4535 38.4535  False
#                Things to do with kids              fun things to do near me     -7.0    1.0 -44.1127 30.1127  False
#                Things to do with kids          fun things to do with family     -7.0    1.0 -52.4535 38.4535  False
#                Things to do with kids              new things to do near me     -7.0    1.0 -52.4535 38.4535  False
#                Things to do with kids                          things to do     11.0 0.9951 -22.8791 44.8791  False
#                Things to do with kids                  things to do near me     -4.0    1.0 -41.1127 33.1127  False
#                Things to do with kids             things to do this weekend     -6.0    1.0 -43.1127 31.1127  False
#   Things to do with kids this weekend                   attractions near me      0.0    1.0 -45.4535 45.4535  False
#   Things to do with kids this weekend           couple date idea fort myers      0.0    1.0 -52.4852 52.4852  False
#   Things to do with kids this weekend             couple date ideas near me      0.0    1.0 -52.4852 52.4852  False
#   Things to do with kids this weekend            couples activities near me      0.0    1.0 -52.4852 52.4852  False
#   Things to do with kids this weekend                   couples dates ideas      1.0    1.0 -44.4535 46.4535  False
#   Things to do with kids this weekend                       cute date ideas      0.5    1.0 -44.9535 45.9535  False
#   Things to do with kids this weekend                date idea this weekend      0.0    1.0 -52.4852 52.4852  False
#   Things to do with kids this weekend                      date night ideas      1.5    1.0 -43.9535 46.9535  False
#   Things to do with kids this weekend              date night ideas near me      0.0    1.0 -52.4852 52.4852  False
#   Things to do with kids this weekend             fun activities fort myers      1.0    1.0 -44.4535 46.4535  False
#   Things to do with kids this weekend                fun activities near me      1.0    1.0 -44.4535 46.4535  False
#   Things to do with kids this weekend                  fun dates fort myers      0.0    1.0 -45.4535 45.4535  False
#   Things to do with kids this weekend  fun places to go with family near me      0.0    1.0 -52.4852 52.4852  False
#   Things to do with kids this weekend              fun things to do near me      0.0    1.0 -45.4535 45.4535  False
#   Things to do with kids this weekend          fun things to do with family      0.0    1.0 -52.4852 52.4852  False
#   Things to do with kids this weekend              new things to do near me      0.0    1.0 -52.4852 52.4852  False
#   Things to do with kids this weekend                          things to do     18.0 0.9438  -24.854  60.854  False
#   Things to do with kids this weekend                  things to do near me      3.0    1.0 -42.4535 48.4535  False
#   Things to do with kids this weekend             things to do this weekend      1.0    1.0 -44.4535 46.4535  False
#                   attractions near me           couple date idea fort myers      0.0    1.0 -45.4535 45.4535  False
#                   attractions near me             couple date ideas near me      0.0    1.0 -45.4535 45.4535  False
#                   attractions near me            couples activities near me      0.0    1.0 -45.4535 45.4535  False
#                   attractions near me                   couples dates ideas      1.0    1.0 -36.1127 38.1127  False
#                   attractions near me                       cute date ideas      0.5    1.0 -36.6127 37.6127  False
#                   attractions near me                date idea this weekend      0.0    1.0 -45.4535 45.4535  False
#                   attractions near me                      date night ideas      1.5    1.0 -35.6127 38.6127  False
#                   attractions near me              date night ideas near me      0.0    1.0 -45.4535 45.4535  False
#                   attractions near me             fun activities fort myers      1.0    1.0 -36.1127 38.1127  False
#                   attractions near me                fun activities near me      1.0    1.0 -36.1127 38.1127  False
#                   attractions near me                  fun dates fort myers      0.0    1.0 -37.1127 37.1127  False
#                   attractions near me  fun places to go with family near me      0.0    1.0 -45.4535 45.4535  False
#                   attractions near me              fun things to do near me      0.0    1.0 -37.1127 37.1127  False
#                   attractions near me          fun things to do with family      0.0    1.0 -45.4535 45.4535  False
#                   attractions near me              new things to do near me      0.0    1.0 -45.4535 45.4535  False
#                   attractions near me                          things to do     18.0 0.7519 -15.8791 51.8791  False
#                   attractions near me                  things to do near me      3.0    1.0 -34.1127 40.1127  False
#                   attractions near me             things to do this weekend      1.0    1.0 -36.1127 38.1127  False
#           couple date idea fort myers             couple date ideas near me      0.0    1.0 -52.4852 52.4852  False
#           couple date idea fort myers            couples activities near me      0.0    1.0 -52.4852 52.4852  False
#           couple date idea fort myers                   couples dates ideas      1.0    1.0 -44.4535 46.4535  False
#           couple date idea fort myers                       cute date ideas      0.5    1.0 -44.9535 45.9535  False
#           couple date idea fort myers                date idea this weekend      0.0    1.0 -52.4852 52.4852  False
#           couple date idea fort myers                      date night ideas      1.5    1.0 -43.9535 46.9535  False
#           couple date idea fort myers              date night ideas near me      0.0    1.0 -52.4852 52.4852  False
#           couple date idea fort myers             fun activities fort myers      1.0    1.0 -44.4535 46.4535  False
#           couple date idea fort myers                fun activities near me      1.0    1.0 -44.4535 46.4535  False
#           couple date idea fort myers                  fun dates fort myers      0.0    1.0 -45.4535 45.4535  False
#           couple date idea fort myers  fun places to go with family near me      0.0    1.0 -52.4852 52.4852  False
#           couple date idea fort myers              fun things to do near me      0.0    1.0 -45.4535 45.4535  False
#           couple date idea fort myers          fun things to do with family      0.0    1.0 -52.4852 52.4852  False
#           couple date idea fort myers              new things to do near me      0.0    1.0 -52.4852 52.4852  False
#           couple date idea fort myers                          things to do     18.0 0.9438  -24.854  60.854  False
#           couple date idea fort myers                  things to do near me      3.0    1.0 -42.4535 48.4535  False
#           couple date idea fort myers             things to do this weekend      1.0    1.0 -44.4535 46.4535  False
#             couple date ideas near me            couples activities near me      0.0    1.0 -52.4852 52.4852  False
#             couple date ideas near me                   couples dates ideas      1.0    1.0 -44.4535 46.4535  False
#             couple date ideas near me                       cute date ideas      0.5    1.0 -44.9535 45.9535  False
#             couple date ideas near me                date idea this weekend      0.0    1.0 -52.4852 52.4852  False
#             couple date ideas near me                      date night ideas      1.5    1.0 -43.9535 46.9535  False
#             couple date ideas near me              date night ideas near me      0.0    1.0 -52.4852 52.4852  False
#             couple date ideas near me             fun activities fort myers      1.0    1.0 -44.4535 46.4535  False
#             couple date ideas near me                fun activities near me      1.0    1.0 -44.4535 46.4535  False
#             couple date ideas near me                  fun dates fort myers      0.0    1.0 -45.4535 45.4535  False
#             couple date ideas near me  fun places to go with family near me      0.0    1.0 -52.4852 52.4852  False
#             couple date ideas near me              fun things to do near me      0.0    1.0 -45.4535 45.4535  False
#             couple date ideas near me          fun things to do with family      0.0    1.0 -52.4852 52.4852  False
#             couple date ideas near me              new things to do near me      0.0    1.0 -52.4852 52.4852  False
#             couple date ideas near me                          things to do     18.0 0.9438  -24.854  60.854  False
#             couple date ideas near me                  things to do near me      3.0    1.0 -42.4535 48.4535  False
#             couple date ideas near me             things to do this weekend      1.0    1.0 -44.4535 46.4535  False
#            couples activities near me                   couples dates ideas      1.0    1.0 -44.4535 46.4535  False
#            couples activities near me                       cute date ideas      0.5    1.0 -44.9535 45.9535  False
#            couples activities near me                date idea this weekend      0.0    1.0 -52.4852 52.4852  False
#            couples activities near me                      date night ideas      1.5    1.0 -43.9535 46.9535  False
#            couples activities near me              date night ideas near me      0.0    1.0 -52.4852 52.4852  False
#            couples activities near me             fun activities fort myers      1.0    1.0 -44.4535 46.4535  False
#            couples activities near me                fun activities near me      1.0    1.0 -44.4535 46.4535  False
#            couples activities near me                  fun dates fort myers      0.0    1.0 -45.4535 45.4535  False
#            couples activities near me  fun places to go with family near me      0.0    1.0 -52.4852 52.4852  False
#            couples activities near me              fun things to do near me      0.0    1.0 -45.4535 45.4535  False
#            couples activities near me          fun things to do with family      0.0    1.0 -52.4852 52.4852  False
#            couples activities near me              new things to do near me      0.0    1.0 -52.4852 52.4852  False
#            couples activities near me                          things to do     18.0 0.9438  -24.854  60.854  False
#            couples activities near me                  things to do near me      3.0    1.0 -42.4535 48.4535  False
#            couples activities near me             things to do this weekend      1.0    1.0 -44.4535 46.4535  False
#                   couples dates ideas                       cute date ideas     -0.5    1.0 -37.6127 36.6127  False
#                   couples dates ideas                date idea this weekend     -1.0    1.0 -46.4535 44.4535  False
#                   couples dates ideas                      date night ideas      0.5    1.0 -36.6127 37.6127  False
#                   couples dates ideas              date night ideas near me     -1.0    1.0 -46.4535 44.4535  False
#                   couples dates ideas             fun activities fort myers      0.0    1.0 -37.1127 37.1127  False
#                   couples dates ideas                fun activities near me      0.0    1.0 -37.1127 37.1127  False
#                   couples dates ideas                  fun dates fort myers     -1.0    1.0 -38.1127 36.1127  False
#                   couples dates ideas  fun places to go with family near me     -1.0    1.0 -46.4535 44.4535  False
#                   couples dates ideas              fun things to do near me     -1.0    1.0 -38.1127 36.1127  False
#                   couples dates ideas          fun things to do with family     -1.0    1.0 -46.4535 44.4535  False
#                   couples dates ideas              new things to do near me     -1.0    1.0 -46.4535 44.4535  False
#                   couples dates ideas                          things to do     17.0  0.816 -16.8791 50.8791  False
#                   couples dates ideas                  things to do near me      2.0    1.0 -35.1127 39.1127  False
#                   couples dates ideas             things to do this weekend      0.0    1.0 -37.1127 37.1127  False
#                       cute date ideas                date idea this weekend     -0.5    1.0 -45.9535 44.9535  False
#                       cute date ideas                      date night ideas      1.0    1.0 -36.1127 38.1127  False
#                       cute date ideas              date night ideas near me     -0.5    1.0 -45.9535 44.9535  False
#                       cute date ideas             fun activities fort myers      0.5    1.0 -36.6127 37.6127  False
#                       cute date ideas                fun activities near me      0.5    1.0 -36.6127 37.6127  False
#                       cute date ideas                  fun dates fort myers     -0.5    1.0 -37.6127 36.6127  False
#                       cute date ideas  fun places to go with family near me     -0.5    1.0 -45.9535 44.9535  False
#                       cute date ideas              fun things to do near me     -0.5    1.0 -37.6127 36.6127  False
#                       cute date ideas          fun things to do with family     -0.5    1.0 -45.9535 44.9535  False
#                       cute date ideas              new things to do near me     -0.5    1.0 -45.9535 44.9535  False
#                       cute date ideas                          things to do     17.5 0.7848 -16.3791 51.3791  False
#                       cute date ideas                  things to do near me      2.5    1.0 -34.6127 39.6127  False
#                       cute date ideas             things to do this weekend      0.5    1.0 -36.6127 37.6127  False
#                date idea this weekend                      date night ideas      1.5    1.0 -43.9535 46.9535  False
#                date idea this weekend              date night ideas near me      0.0    1.0 -52.4852 52.4852  False
#                date idea this weekend             fun activities fort myers      1.0    1.0 -44.4535 46.4535  False
#                date idea this weekend                fun activities near me      1.0    1.0 -44.4535 46.4535  False
#                date idea this weekend                  fun dates fort myers      0.0    1.0 -45.4535 45.4535  False
#                date idea this weekend  fun places to go with family near me      0.0    1.0 -52.4852 52.4852  False
#                date idea this weekend              fun things to do near me      0.0    1.0 -45.4535 45.4535  False
#                date idea this weekend          fun things to do with family      0.0    1.0 -52.4852 52.4852  False
#                date idea this weekend              new things to do near me      0.0    1.0 -52.4852 52.4852  False
#                date idea this weekend                          things to do     18.0 0.9438  -24.854  60.854  False
#                date idea this weekend                  things to do near me      3.0    1.0 -42.4535 48.4535  False
#                date idea this weekend             things to do this weekend      1.0    1.0 -44.4535 46.4535  False
#                      date night ideas              date night ideas near me     -1.5    1.0 -46.9535 43.9535  False
#                      date night ideas             fun activities fort myers     -0.5    1.0 -37.6127 36.6127  False
#                      date night ideas                fun activities near me     -0.5    1.0 -37.6127 36.6127  False
#                      date night ideas                  fun dates fort myers     -1.5    1.0 -38.6127 35.6127  False
#                      date night ideas  fun places to go with family near me     -1.5    1.0 -46.9535 43.9535  False
#                      date night ideas              fun things to do near me     -1.5    1.0 -38.6127 35.6127  False
#                      date night ideas          fun things to do with family     -1.5    1.0 -46.9535 43.9535  False
#                      date night ideas              new things to do near me     -1.5    1.0 -46.9535 43.9535  False
#                      date night ideas                          things to do     16.5  0.845 -17.3791 50.3791  False
#                      date night ideas                  things to do near me      1.5    1.0 -35.6127 38.6127  False
#                      date night ideas             things to do this weekend     -0.5    1.0 -37.6127 36.6127  False
#              date night ideas near me             fun activities fort myers      1.0    1.0 -44.4535 46.4535  False
#              date night ideas near me                fun activities near me      1.0    1.0 -44.4535 46.4535  False
#              date night ideas near me                  fun dates fort myers      0.0    1.0 -45.4535 45.4535  False
#              date night ideas near me  fun places to go with family near me      0.0    1.0 -52.4852 52.4852  False
#              date night ideas near me              fun things to do near me      0.0    1.0 -45.4535 45.4535  False
#              date night ideas near me          fun things to do with family      0.0    1.0 -52.4852 52.4852  False
#              date night ideas near me              new things to do near me      0.0    1.0 -52.4852 52.4852  False
#              date night ideas near me                          things to do     18.0 0.9438  -24.854  60.854  False
#              date night ideas near me                  things to do near me      3.0    1.0 -42.4535 48.4535  False
#              date night ideas near me             things to do this weekend      1.0    1.0 -44.4535 46.4535  False
#             fun activities fort myers                fun activities near me      0.0    1.0 -37.1127 37.1127  False
#             fun activities fort myers                  fun dates fort myers     -1.0    1.0 -38.1127 36.1127  False
#             fun activities fort myers  fun places to go with family near me     -1.0    1.0 -46.4535 44.4535  False
#             fun activities fort myers              fun things to do near me     -1.0    1.0 -38.1127 36.1127  False
#             fun activities fort myers          fun things to do with family     -1.0    1.0 -46.4535 44.4535  False
#             fun activities fort myers              new things to do near me     -1.0    1.0 -46.4535 44.4535  False
#             fun activities fort myers                          things to do     17.0  0.816 -16.8791 50.8791  False
#             fun activities fort myers                  things to do near me      2.0    1.0 -35.1127 39.1127  False
#             fun activities fort myers             things to do this weekend      0.0    1.0 -37.1127 37.1127  False
#                fun activities near me                  fun dates fort myers     -1.0    1.0 -38.1127 36.1127  False
#                fun activities near me  fun places to go with family near me     -1.0    1.0 -46.4535 44.4535  False
#                fun activities near me              fun things to do near me     -1.0    1.0 -38.1127 36.1127  False
#                fun activities near me          fun things to do with family     -1.0    1.0 -46.4535 44.4535  False
#                fun activities near me              new things to do near me     -1.0    1.0 -46.4535 44.4535  False
#                fun activities near me                          things to do     17.0  0.816 -16.8791 50.8791  False
#                fun activities near me                  things to do near me      2.0    1.0 -35.1127 39.1127  False
#                fun activities near me             things to do this weekend      0.0    1.0 -37.1127 37.1127  False
#                  fun dates fort myers  fun places to go with family near me      0.0    1.0 -45.4535 45.4535  False
#                  fun dates fort myers              fun things to do near me      0.0    1.0 -37.1127 37.1127  False
#                  fun dates fort myers          fun things to do with family      0.0    1.0 -45.4535 45.4535  False
#                  fun dates fort myers              new things to do near me      0.0    1.0 -45.4535 45.4535  False
#                  fun dates fort myers                          things to do     18.0 0.7519 -15.8791 51.8791  False
#                  fun dates fort myers                  things to do near me      3.0    1.0 -34.1127 40.1127  False
#                  fun dates fort myers             things to do this weekend      1.0    1.0 -36.1127 38.1127  False
#  fun places to go with family near me              fun things to do near me      0.0    1.0 -45.4535 45.4535  False
#  fun places to go with family near me          fun things to do with family      0.0    1.0 -52.4852 52.4852  False
#  fun places to go with family near me              new things to do near me      0.0    1.0 -52.4852 52.4852  False
#  fun places to go with family near me                          things to do     18.0 0.9438  -24.854  60.854  False
#  fun places to go with family near me                  things to do near me      3.0    1.0 -42.4535 48.4535  False
#  fun places to go with family near me             things to do this weekend      1.0    1.0 -44.4535 46.4535  False
#              fun things to do near me          fun things to do with family      0.0    1.0 -45.4535 45.4535  False
#              fun things to do near me              new things to do near me      0.0    1.0 -45.4535 45.4535  False
#              fun things to do near me                          things to do     18.0 0.7519 -15.8791 51.8791  False
#              fun things to do near me                  things to do near me      3.0    1.0 -34.1127 40.1127  False
#              fun things to do near me             things to do this weekend      1.0    1.0 -36.1127 38.1127  False
#          fun things to do with family              new things to do near me      0.0    1.0 -52.4852 52.4852  False
#          fun things to do with family                          things to do     18.0 0.9438  -24.854  60.854  False
#          fun things to do with family                  things to do near me      3.0    1.0 -42.4535 48.4535  False
#          fun things to do with family             things to do this weekend      1.0    1.0 -44.4535 46.4535  False
#              new things to do near me                          things to do     18.0 0.9438  -24.854  60.854  False
#              new things to do near me                  things to do near me      3.0    1.0 -42.4535 48.4535  False
#              new things to do near me             things to do this weekend      1.0    1.0 -44.4535 46.4535  False
#                          things to do                  things to do near me    -15.0 0.9168 -48.8791 18.8791  False
#                          things to do             things to do this weekend    -17.0  0.816 -50.8791 16.8791  False
#                  things to do near me             things to do this weekend     -2.0    1.0 -39.1127 35.1127  False
# -------------------------------------------------------------------------------------------------------------------

# %%
tukey_results.pvalues < 0.1
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False])
